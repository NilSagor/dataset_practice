# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup

# After response = requests.get() 
from lxml import html

# %%
web_site = "https://www.fifaindex.com/teams/?page=1&type=1"
page = requests.get(web_site)
# print(page.text)
soup = BeautifulSoup(page.content, 'lxml')
# print(soup.prettify())
tree = html.fromstring(soup.text)
# results_elem = soup.find_all("table", class_="table-teams")
# for job_elem in results_elem:
#     print(job_elem, end="\n")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-84-c883ecc772a2> in <module>
#       2 page = requests.get(web_site)
#       3 # print(page.text)
# ----> 4 soup = BeautifulSoup(page.content, 'lxml')
#       5 # print(soup.prettify())
#       6 tree = html.fromstring(soup.text)
#
# ~/Library/Python/3.8/lib/python/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     241             builder_class = builder_registry.lookup(*features)
#     242             if builder_class is None:
# --> 243                 raise FeatureNotFound(
#     244                     "Couldn't find a tree builder with the features you "
#     245                     "requested: %s. Do you need to install a parser library?"
#
# ...

# %%
base_url = "https://understat.com/match/"
match = str(input("Please enter the match id: "))
url = base_url + match
# Out:
# Please enter the match id: 18358

# %%
print(url)
# Out:
# https://understat.com/match/18358

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <base href="https://understat.com/"/>
# <title>Nottingham Forest 1 - 0 Crystal Palace (November 12 2022) | EPL | 2022/2023 | xG | Understat.com</title>
# <meta charset="utf-8"/>
# <meta content="Nottingham Forest 1 - 0 Crystal Palace. Check out detailed player statistic, goals, assists, key passes, xG, shot map, xGplot." name="description"/>
# <meta content="Nottingham Forest, Crystal Palace, EPL, 2022/2023, (November 12 2022), xG, expected goals, shot map" name="Keywords"/>
# <link href="apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="understat" name="apple-mobile-web-app-title"/>
# <meta content="understat" name="application-name"/>
# ...

# %%
print(lxml.__class__.attribute)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-cfb7d6a69fa0> in <module>
# ----> 1 print(lxml.__class__.attribute)
#
# AttributeError: type object 'module' has no attribute 'attribute'

# %%
base_url = "https://en.wikipedia.org/wiki/2022%E2%80%9323_Premier_League"
res = requests.get(base_url)
soup = BeautifulSoup(res.content, "html.parser")
len(soup.find_all("table", {"class": "wikitable"}))
# Out:
# 10

# %%
###### table = soup.select_one("#League_table").parent.find_next_sibling("table")
rows = table.find_all("tr")
for row in rows:
    team_name = row.find("th").text.strip()
    gf = row.find_all("td")[0]
    print(f"team_name {team_name} - {gf}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-48622171d62b> in <module>
#       3 for row in rows:
#       4     team_name = row.find("th").text.strip()
# ----> 5     gf = row.find_all("td")[0]
#       6     print(f"team_name {team_name} - {gf}")
#
# IndexError: list index out of range
