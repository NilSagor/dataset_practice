# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
no_balls = 1000
#x = np.random.multivariate_normal(3, 2.5, size=no_balls)

#x = [random.triangular() for i in range(no_balls)]
#y = [random.gauss(0.7, 0.25) for i in range(no_balls)]
#colors = [random.randint(1, 2) for i in range(no_balls)]
#areas = [math.pi * random.randint(5, 15)**2 for i in range(500)]



colors = np.random.randint(1,2)

cov = np.array([[6, -3], [-3, 3.5]])
x = np.random.multivariate_normal([0, 0], cov, size=1000)

#cov = np.array([[6, -3], [-3, 3.5]])
plt.figure(figsize=(10,5))
plt.scatter(x[:,0], x[:,1])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Library/Python/3.8/lib/python/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4213             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4214                 colors = mcolors.to_rgba_array(c)
#    4215             except (TypeError, ValueError) as err:
#
# ~/Library/Python/3.8/lib/python/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     362
# --> 363     if len(c) == 0:
#     364         return np.zeros((0, 4), float)
#
# TypeError: len() of unsized object
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-48837f8e54fd> in <module>
#      16 #cov = np.array([[6, -3], [-3, 3.5]])
# ...

# %%
plt.figure(figsize=(14,8))

mu_first = [0.20, 0.20]
mu_second = [-0.25, -0.25]
cov_first = [[0.025, 0.0], [0.0, 0.025]]
cov_second = [[0.025, 0.0], [0.0, 0.025]]

x1,y1 = np.random.multivariate_normal(mu_first, cov_first, 500).T
x2,y2 = np.random.multivariate_normal(mu_second, cov_second, 500).T

plt.scatter(x1,y1,c='r', label="LUAD")
plt.scatter(x2,y2,c='b', label="LUSC")
plt.xticks([])
plt.yticks([])
plt.legend()
plt.show()
plt.savefig("luad_lusc_classification.png")

# %%
from scipy.interpolate import interp1d, make_interp_spline

# %%
x = np.random.normal(0, 140, 150)
#y = np.linspace(250,2250, 150)
y =multivariate_normal.pdf(x, mean=2.5, cov=0.5)
plt.plot(x, y)
plt.show()

# %%
#x = np.random.normal(0,140, 500)
x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = np.array([20, 30, 5, 12, 39, 48, 50, 3])

X_Y_Spline = make_interp_spline(x, y)

X_ = np.linspace(x.min(), x.max(), 500)
Y_ = X_Y_Spline(X_)
plt.plot(X_, Y_)

# %%
from scipy.interpolate import interp1d

x = np.arange(0, 150)
y = np.exp(-x/5.0)
#y = np.arange(250, 2500, step=250)
#xnew = np.random.randint(0,150, 3)
#f = interp1d(x, y)
#ynew = f(xnew)
plt.figure(figsize=(8,5))
plt.plot(x,y,)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.yticks([])
#plt.yticks(np.arange(250, 2500, step=250))
plt.show()

# %%
import networkx as nx

# %%
G = nx.path_graph(4)

# %%
nx.add_path(G, )

# %%
G = nx.Graph()

# %%
nx.add_path(G, [1,2,3])

# %%
G

# %%
list(G.nodes())
# Out:
# [1, 2, 3]

# %%
list(G.edges())
# Out:
# [(1, 2), (2, 3)]

# %%
x=list(G.edges())

# %%
x
# Out:
# [(1, 2), (2, 3)]

# %%
x[0]
# Out:
# (1, 2)

# %%
x[0][0]
# Out:
# 1

# %%
nx.add_path(G, [10,11,12], weight=7)

# %%
list(G.nodes())
# Out:
# [1, 2, 3, 10, 11, 12]

# %%
list(G.nodes()[data=True])
# Out:
#   File "<ipython-input-143-fb8f59c5fd8e>", line 1
#     list(G.nodes()[data=True])
#                        ^
# SyntaxError: invalid syntax

# %%
G.number_of_edges()
# Out:
# 4

# %%
G.number_of_nodes()
# Out:
# 6

# %%
sorted(nx.common_neighbors(G, 1,10))
# Out:
# []

# %%
p = nx.complete_graph(5)

# %%
sorted(nx.common_neighbors(p,1,4))
# Out:
# [0, 2, 3]

# %%
nx.draw(G)

# %%
nx.draw_circular(G)

# %%
pos = nx.circular_layout(G)
nx.draw(G, pos=pos)

# %%
n = nx.path_graph(5)
pos = nx.planar_layout(n)

# %%
nx.draw(n, pos=pos)

# %%
nx.draw(n.subgraph([0,1,2]), pos=pos, node_color="red")

# %%
pos = nx.spectral_layout(n)
nx.draw(n, pos=pos, node_color="red")

# %%
nx.draw_spectral(n)

# %%
nx.draw_spectral(n, node_color="green", with_labels=True)

# %%
nx.draw_spring(n, with_labels=True)

# %%
nx.draw_shell(n)

# %%
d = nx.dodecahedral_graph()
nx.draw(d, with_labels=True)
plt.draw()

# %%
G = nx.complete_graph(100)
nx.draw(G, with_labels=True)

# %%
G = nx.wheel_graph(10)
nx.draw(G, with_labels=True)

# %%
H = nx.wheel_graph([2,4,5,6,7,10,12,14,16,20,10])
nx.draw(H, with_labels=True)

# %%
G = nx.turan_graph(10,2)
nx.draw(G, with_labels=True)

# %%
G = nx.trivial_graph()

# %%
nx.draw(G, with_labels=True)

# %%
G = nx.star_graph(10)
nx.draw(G, with_labels=True)

# %%
G = nx.lollipop_graph(10, 2)
nx.draw(G, with_labels=True)

# %%
G = nx.ladder_graph(10)
nx.draw(G, with_labels=True)

# %%
G = nx.full_rary_tree(5,10)
nx.draw(G, with_labels=True)

# %%
import scipy as sp
import scipy.io 
import io

# %%
G = nx.path_graph(5)

# %%
nx.draw(G, with_labels=True)

# %%
m = nx.to_scipy_sparse_array(G)

# %%
print(m)
# Out:
#   (0, 1)	1
#   (1, 0)	1
#   (1, 2)	1
#   (2, 1)	1
#   (2, 3)	1
#   (3, 2)	1
#   (3, 4)	1
#   (4, 3)	1

# %%
fh = io.BytesIO()

# %%
sp.io.mmwrite(fh, m)

# %%
print(fh.getvalue().decode('utf-8'))
# Out:
# %%MatrixMarket matrix coordinate integer symmetric
# %
# 5 5 4
# 2 1 1
# 3 2 1
# 4 3 1
# 5 4 1

# %%
fh.seek(0)
H = nx.from_scipy_sparse_matrix(sp.io.mmread(fh))
# Out:
# <ipython-input-198-ca313cdb2ccd>:2: DeprecationWarning:
#
# The scipy.sparse array containers will be used instead of matrices
# in Networkx 3.0. Use `from_scipy_sparse_array` instead.
#   H = nx.from_scipy_sparse_matrix(sp.io.mmread(fh))

# %%
nx.draw(H, with_labels=True)

# %%
G = nx.Graph()
G.add_edge(1,2, weight=4.7)
G.add_edges_from([(1,3), (2,3), (4,3)], color="red")
G.add_edges_from([(5,6, {"color":"green"}), (1,4,{"weight":8}), (3,5, {"time":5.6})])
nx.draw(G, with_labels=True)

# %%
G.add_edges_from([(5,2,{"weight":4.2, "color":"yellow"})])
nx.draw(G, with_labels=True)

# %%
list(G.nodes), list(G.edges), list(G.adj), list(G.degree)
# Out:
# ([1, 2, 3, 4, 5, 6],
#  [(1, 2), (1, 3), (1, 4), (2, 3), (2, 5), (3, 4), (3, 5), (5, 6)],
#  [1, 2, 3, 4, 5, 6],
#  [(1, 3), (2, 3), (3, 4), (4, 2), (5, 3), (6, 1)])

# %%
G[5][2]["weight"]=3.5

# %%
list(G.edges(data=True))
# Out:
# [(1, 2, {'weight': 4.7}),
#  (1, 3, {'color': 'red'}),
#  (1, 4, {'weight': 8}),
#  (2, 3, {'color': 'red'}),
#  (2, 5, {'weight': 3.5, 'color': 'yellow'}),
#  (3, 4, {'color': 'red'}),
#  (3, 5, {'time': 5.6}),
#  (5, 6, {'color': 'green'})]

# %%
list(G.nodes(data=True))
# Out:
# [(1, {}), (2, {}), (3, {}), (4, {}), (5, {}), (6, {})]

# %%
list(G.degree)
# Out:
# [(1, 3), (2, 3), (3, 4), (4, 2), (5, 3), (6, 1)]

# %%
G.nodes.data()
# Out:
# NodeDataView({1: {}, 2: {}, 3: {}, 4: {}, 5: {}, 6: {}})

# %%
G.edges.data()
# Out:
# EdgeDataView([(1, 2, {'weight': 4.7}), (1, 3, {'color': 'red'}), (1, 4, {'weight': 8}), (2, 3, {'color': 'red'}), (2, 5, {'weight': 3.5, 'color': 'yellow'}), (3, 4, {'color': 'red'}), (3, 5, {'time': 5.6}), (5, 6, {'color': 'green'})])

# %%
DG = nx.DiGraph()

# %%
DG.add_weighted_edges_from([(1, 2, 0.5), (3, 1, 0.75), (4, 5, 3.6), (2,5, 6.8)])

# %%
nx.draw(DG, with_labels=True)

# %%
label = nx.get_edge_attributes(DG, "weight")
nx.draw(DG, labels=label, with_labels=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-231-c3a4d3f1d90b> in <module>
#       1 label = nx.get_edge_attributes(DG, "weight")
# ----> 2 nx.draw(DG, labels=label, with_labels=True)
#
# ~/Library/Python/3.8/lib/python/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     119         kwds["with_labels"] = "labels" in kwds
#     120
# --> 121     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122     ax.set_axis_off()
#     123     plt.draw_if_interactive()
#
# ~/Library/Python/3.8/lib/python/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     304     draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     305     if with_labels:
# --> 306         draw_networkx_labels(G, pos, **label_kwds)
#     307     plt.draw_if_interactive()
#     308
#
# ...
